# %%
idade = int(input("Digite sua idade:"))
print("Sua idade é %i" % idade)
# Out:
# Digite sua idade:45
# Sua idade é 45

# %%
nascimento = int(input("Digite o ano do seu nascimento"))
ano_atual = int(input("Digite o ano atual"))

idade = ano_atual - nascimento
print("Sua idade em %i é %i anos." % (ano_atual,idade))
# Out:
# Digite o ano do seu nascimento1900
# Digite o ano atual2021
# Sua idade em 2021 é 121 anos.

# %%
idade = int(input("Idade"))
altura = float(input("Altura"))

print("Sua idade é %i e altura é %.2f" % (idade, altura))
# Out:
# Idade45
# Altura1.95
# Sua idade é 45 e altura é 1.95

# %%
numero1 = int(input("Digite o primeiro número para somar: "))
numero2 = int(input("Digite o segundo numero para somar: "))

soma = numero1 + numero2
subt = numero1 - numero2
mult = numero1 * numero2
div = numero1 / numero2


print("A soma deles é %i" % (soma))
print("%i + %i = %i" % (numero1,numero2,soma))

print("A subt deles é %i" % (subt))
print("A mult deles é %i" % (mult))
print("A div deles é %i" % (div))
# Out:
# Digite o primeiro número para somar: 7
# Digite o segundo numero para somar: 7
# A soma deles é 14
# 7 + 7 = 14
# A subt deles é 0
# A mult deles é 49
# A div deles é 1

# %%
base = float(input("Base: "))
altura = float(input("Altura: "))
area = base * altura

print("A área do retângulo é %.2f" % area)
# Out:
# Base: 1.35
# Altura2.80
# A área do retângulo é 3.78

# %%
preco = float(input(" Digite o preço: "))
qde = float(input("Digite a quantidade: "))
total = preco * qde

print("O valor total da compra é R$ %.2f" % total)
# Out:
#  Digite o preço: 2.90
# Digite a quantidade: 35
# O valor total da compra é 101.50

# %%
# def define uma função

def hello (nome,idade,cidade):
  print("Olá, ",nome, "voce tem", idade,"anos e mora em", cidade)

nome = str(input("Nome:"))
idade = str(input("Idade:"))
cidade = str(input("Cidade:"))
hello(nome, idade,cidade)
# Out:
# Nome:Rodrigo
# Idade:45
# Cidade:SP
# Olá,  Rodrigo voce tem 45 anos e mora em SP

# %%
def calculando_imc(peso,altura):
  print(peso / altura ** 2)

peso = float(input("Peso: "))
altura = float(input("Altura: "))
calculando_imc(peso,altura)
# Out:
# Peso: 90
# Altura: 1.90
# 24.930747922437675

# %%
def calculando_imc(peso,altura):
  imc = (peso / altura **2)
  if(imc < 18.5):
    print("Você está com baixo peso.")
  else:
    if(imc <= 24.9):
      print("Você está com peso normal.")
    else:
        if(imc <=29.9):
          print("Você está com sobrepeso.")
        else:
            if(imc < 34.9):
              print("Você está com obesidade grau 1.")
            else:
                print("Cuidado. Seu grau de obesidade é severo.")

peso = float(input("Peso: "))
altura = float(input("Altura: "))
calculando_imc(peso,altura)
# Out:
# Peso: 90
# Altura: 1.90
# Você está com sobrepeso.

# %%
import math

a = math.ceil(1.5)
b = math.floor(1.5)
print(a)
print(b)
# Out:
# 2
# 1

# %%
def temperatura(celsius, fahrenheit):
  cels = float(celsius)
  fah = float(fahrenheit)

cels = float(input("Digite a temperatura em Celsius: "))
fah = cels*1.8+32.00

print("O valor da temperatura em Fahrenheit é %.2f" % fah)
# Out:
# Digite a temperatura em Celsius: 45.2
# O valor da temperatura em Fahrenheit é 113.36

# %%
def temperatura(celsius, fahrenheit):
  cels = float(celsius)
  fah = float(fahrenheit)

fah = float(input("Digite a temperatura em Fahrenheit: "))
cels = (fah - 32) / 1.8

print("O valor da temperatura em Celsius é %.2f" % cels)
# Out:
# Digite a temperatura em Fahrenheit: 88
# O valor da temperatura em Celsius é 31.11

# %%
def calcular_salario(horas_trabalhadas,valor_hora):
  horas = float(horas_trabalhadas)
  valor = float(valor_hora)
  if horas <= 40:
    salario = horas*valor_hora
  else:
      hora_extra = horas - 40
      salario = 40*taxa + (hora_extra*(1.5*taxa))
  return salario
      
horas = float(input("Total de horas trabalhadas: "))
taxa = float(input("Valor da hora trabalhada: "))
salário = calcular_salario(horas,taxa)

print("O valor de seus rendimentos é de R$ %.2f" % salário)
# Out:
# Total de horas trabalhadas: 55
# Valor da hora trabalhada: 200
# O valor de seus rendimentos é de R$ 12500.00
